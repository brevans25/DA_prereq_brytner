# %%
print("Hello Word")
# Out:
# Hello Word

# %% [markdown]
# # About Me
# My name is Brytner. <br>
# I live in Louisville, Kentucky with Cairo, my 13yo Shiba Inu.<br>
# I am excited to dive into this content and expand my skillset.<br>
# It's going to be a fascinating journey!
